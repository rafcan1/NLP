# %% [markdown]
# Natural Language Processing 2024/SZ 15-PJN-LMT-11
# Exercise #11
# Submit solutions with code as Jupyter Notebook using MS Teams assignments. Each
# task is 1 point. Deadline: 07.01.2025
# Use Vertex AI Colab Enterprise
# https://www.cloudskillsboost.google/focuses/86502?catalog_rank=%7B%22rank%22%3A3%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=31485286%3Futm_source%3Dcgc-site&utm_campaign=FY24-Q2-global-websiteskillsboost&utm_content=developers&utm_medium=et&utm_term=-
# base on:
# https://github.com/GoogleCloudPlatform/generative-ai/blob/main/vision/gettingstarted/image_editing_maskmode.ipynb

# %%
# %pip install --quiet --upgrade --user google-cloud-aiplatform
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 42.9 MB/s eta 0:00:00
#   WARNING: The script tb-gcp-uploader is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import IPython

app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import sys

# Additional authentication is required for Google Colab
if "google.colab" in sys.modules:
    # Authenticate user to Google Cloud
    from google.colab import auth

    auth.authenticate_user()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-4-e63182c8efd4> in <cell line: 4>()
#       6     from google.colab import auth
#       7
# ----> 8     auth.authenticate_user()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/auth.py in authenticate_user(clear_output, project_id)
#     258   if not _check_adc(_CredentialType.USER):
#     259     if use_auth_ephem:
# --> 260       _message.blocking_request(
#     261           'request_auth',
#     262           request={'authType': 'auth_user_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# ...

# %% [markdown]
# 1. Using Vertex AI chat, generate a prompt to generate an image (1 point)
# In the prompt, include generating a human, an animal, and an object
# Example prompt: Create a prompt with a person, an object, and an animal. This
# prompt will generate an image

# %% [markdown]
# Create an image with a woman, a mobile phone and a dog.![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Generate image with Imagen (1 point)
# Example prompt: Create an image showing a cheerful middle-aged man in a
# bright blue jacket, standing next to a red sports car parked on a wet street. The
# man is holding a sign with the text 'Welcome to Sunnyville!' written in bold
# letters. On the left leg of the man, stay white big dog. Despite the text, the
# weather is cloudy with a light drizzle, and the street is reflecting the grey sky.
# Surrounding the scene, there are a few bare trees and a small row of storefronts
# in the background

# %% [markdown]
# 3. Inpainting-insert with Semantic maskMode (1 point)
# Replace animal which you add with some other animal
# Tip: use “inpainting-insert” and “semantic” mask mode, remember about
# segmentation class

# %% [markdown]
# 4. Inpainting-remove with Semantic maskMode (1 point)
# Replace object with another object

# %% [markdown]
# 5. Inpainting-insert with Background maskMode (1 point)
# Edit the background of an image
